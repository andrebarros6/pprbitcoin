# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
btc_eur = pd.read_csv(r"C:\Users\abarr\Documents\projects\pprbitcoin\v0\BTC_EUR Kraken Historical Data (1).csv")
btc_eur.head()
# Out:
#          Date      Price       Open       High       Low    Vol. Change %
# 0  10/01/2025   94,201.1   97,221.1  107,410.9  88,620.1  12.57K   -3.08%
# 1  09/01/2025   97,190.7   92,600.0  100,075.1  91,620.6   8.62K    4.96%
# 2  08/01/2025   92,600.0  101,384.8  105,564.7  92,000.1  10.62K   -8.66%
# 3  07/01/2025  101,384.8   90,922.1  104,408.9  89,128.8  12.01K   11.46%
# 4  06/01/2025   91,358.6   92,278.0   93,210.0  90,824.0   0.41K   -1.00%

# %%
btc_eur.dtypes
# Out:
# Date        object
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
btc_eur['Date'] = pd.to_datetime(btc_eur['Date'])

# %%
btc_eur['year'] =btc_eur['Date'].dt.year

# %%
btc_eur.head()
# Out:
#         Date      Price       Open       High       Low    Vol. Change %  year
# 0 2025-10-01   94,201.1   97,221.1  107,410.9  88,620.1  12.57K   -3.08%  2025
# 1 2025-09-01   97,190.7   92,600.0  100,075.1  91,620.6   8.62K    4.96%  2025
# 2 2025-08-01   92,600.0  101,384.8  105,564.7  92,000.1  10.62K   -8.66%  2025
# 3 2025-07-01  101,384.8   90,922.1  104,408.9  89,128.8  12.01K   11.46%  2025
# 4 2025-06-01   91,358.6   92,278.0   93,210.0  90,824.0   0.41K   -1.00%  2025

# %%
btc_eur['Price'] = btc_eur['Price'].str.replace(',','')
btc_eur['Price'] = btc_eur['Price'].astype(float)

# %%
btc_eur.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open                object
# High                object
# Low                 object
# Vol.                object
# Change %            object
# year                 int32
# dtype: object

# %%
imob_pt = pd.read_csv(r"C:\Users\abarr\Documents\projects\pprbitcoin\v0\m2-casas-PT.csv")
imob_pt.head()
# Out:
#           Mes  Preco m2 [EUR] Variacao mensal Variacao trimestral  \
# 0  01-09-2025            2943          -0,30%               1,60%
# 1  01-08-2025            2951           0,90%               3,50%
# 2  01-07-2025            2926           1,00%               3,90%
# 3  01-06-2025            2898           1,70%               4,40%
# 4  01-05-2025            2851           1,20%               4,00%
#
#   Variacao anual
# 0          7,60%
# 1          8,40%
# 2          8,50%
# 3          8,00%
# 4          7,40%

# %%
imob_pt['Date'] = pd.to_datetime(imob_pt['Mes'], format='%d-%m-%Y')

# %%
imob_pt.head()
# Out:
#           Mes  Preco m2 [EUR] Variacao mensal Variacao trimestral  \
# 0  01-09-2025            2943          -0,30%               1,60%
# 1  01-08-2025            2951           0,90%               3,50%
# 2  01-07-2025            2926           1,00%               3,90%
# 3  01-06-2025            2898           1,70%               4,40%
# 4  01-05-2025            2851           1,20%               4,00%
#
#   Variacao anual       Date
# 0          7,60% 2025-09-01
# 1          8,40% 2025-08-01
# 2          8,50% 2025-07-01
# 3          8,00% 2025-06-01
# 4          7,40% 2025-05-01

# %%
imob_pt['year'] = imob_pt['Date'].dt.year

# %%
imob_pt['month'] = imob_pt['Date'].dt.month

# %%
imob_pt.head(9)
# Out:
#           Mes  Preco m2 [EUR] Variacao mensal Variacao trimestral  \
# 0  01-09-2025            2943          -0,30%               1,60%
# 1  01-08-2025            2951           0,90%               3,50%
# 2  01-07-2025            2926           1,00%               3,90%
# 3  01-06-2025            2898           1,70%               4,40%
# 4  01-05-2025            2851           1,20%               4,00%
# 5  01-04-2025            2817           1,50%               4,60%
# 6  01-03-2025            2775           1,20%              -1,90%
# 7  01-02-2025            2742           1,80%              -1,50%
# 8  01-01-2025            2693          -4,70%              -1,50%
#
#   Variacao anual       Date  year  month
# 0          7,60% 2025-09-01  2025      9
# 1          8,40% 2025-08-01  2025      8
# 2          8,50% 2025-07-01  2025      7
# 3          8,00% 2025-06-01  2025      6
# 4          7,40% 2025-05-01  2025      5
# 5          7,40% 2025-04-01  2025      4
# 6          6,30% 2025-03-01  2025      3
# 7          5,60% 2025-02-01  2025      2
# 8          4,30% 2025-01-01  2025      1

# %%
imob_pt['Variacao mensal'] = imob_pt['Variacao mensal'].str.replace('%','')
imob_pt['Variacao mensal'] = imob_pt['Variacao mensal'].str.replace(',','.')
imob_pt['Variacao mensal'] = imob_pt['Variacao mensal'].astype(float)

# %%
imob_pt['Variacao trimestral'] = imob_pt['Variacao trimestral'].str.replace('%','')
imob_pt['Variacao trimestral'] = imob_pt['Variacao trimestral'].str.replace(',','.')
imob_pt['Variacao trimestral'] = imob_pt['Variacao trimestral'].astype(float)

# %%
imob_pt['Variacao anual'] = imob_pt['Variacao anual'].str.replace('%','')
imob_pt['Variacao anual'] = imob_pt['Variacao anual'].str.replace(',','.')
imob_pt['Variacao anual'] = imob_pt['Variacao anual'].astype(float)

# %%
imob_pt.dtypes
# Out:
# Mes                            object
# Preco m2 [EUR]                  int64
# Variacao mensal               float64
# Variacao trimestral           float64
# Variacao anual                float64
# Date                   datetime64[ns]
# year                            int32
# month                           int32
# dtype: object

# %%
imob_pt.rename(columns={'Variacao mensal':'Variacao mensal [%]', 'Variacao trimestral':'Variacao trimestral [%]', 'Variacao anual':'Variacao anual [%]'}, inplace=True)

# %%
imob_pt.head()
# Out:
#           Mes  Preco m2 [EUR]  Variacao mensal [%]  Variacao trimestral [%]  \
# 0  01-09-2025            2943                 -0.3                      1.6
# 1  01-08-2025            2951                  0.9                      3.5
# 2  01-07-2025            2926                  1.0                      3.9
# 3  01-06-2025            2898                  1.7                      4.4
# 4  01-05-2025            2851                  1.2                      4.0
#
#    Variacao anual [%]       Date  year  month
# 0                 7.6 2025-09-01  2025      9
# 1                 8.4 2025-08-01  2025      8
# 2                 8.5 2025-07-01  2025      7
# 3                 8.0 2025-06-01  2025      6
# 4                 7.4 2025-05-01  2025      5

# %%
df = btc_eur.merge(imob_pt[['Date','Preco m2 [EUR]']], on='Date', how='right')

df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %', 'year',
#        'Preco m2 [EUR]'],
#       dtype='object')

# %%
df.head(10)
# Out:
#         Date     Price       Open       High       Low    Vol. Change %  year  \
# 0 2025-09-01   97190.7   92,600.0  100,075.1  91,620.6   8.62K    4.96%  2025
# 1 2025-08-01   92600.0  101,384.8  105,564.7  92,000.1  10.62K   -8.66%  2025
# 2 2025-07-01  101384.8   90,922.1  104,408.9  89,128.8  12.01K   11.46%  2025
# 3 2025-06-01   91358.6   92,278.0   93,210.0  90,824.0   0.41K   -1.00%  2025
# 4 2025-05-01   92278.0   83,196.8   99,344.0  82,271.3  14.29K   10.91%  2025
# 5 2025-04-01   83202.1   76,238.1   84,308.8  67,500.1  15.62K    9.06%  2025
# 6 2025-03-01   76292.4   81,300.1   91,783.2  70,678.9  16.95K   -6.20%  2025
# 7 2025-02-01   81334.0   98,896.6   99,290.7  75,200.1  14.98K  -17.75%  2025
# 8 2025-01-01   98888.8   90,166.7  105,882.8  87,638.7  17.43K    9.67%  2025
# 9 2024-12-01   90168.1   91,134.5  102,888.0  87,025.3  23.48K   -1.06%  2024
#
#    Preco m2 [EUR]
# 0            2943
# 1            2951
# 2            2926
# 3            2898
# 4            2851
# 5            2817
# 6            2775
# 7            2742
# 8            2693
# 9            2827

# %%
df.drop(columns=(['Open','High','Low','Change %','Vol.']), inplace=True)

# %%
df
# Out:
#           Date     Price  year  Preco m2 [EUR]
# 0   2025-09-01   97190.7  2025            2943
# 1   2025-08-01   92600.0  2025            2951
# 2   2025-07-01  101384.8  2025            2926
# 3   2025-06-01   91358.6  2025            2898
# 4   2025-05-01   92278.0  2025            2851
# ..         ...       ...   ...             ...
# 124 2015-05-01     208.3  2015            1103
# 125 2015-04-01     210.3  2015            1078
# 126 2015-03-01     228.4  2015            1078
# 127 2015-02-01     220.9  2015            1068
# 128 2015-01-01     193.5  2015             969
#
# [129 rows x 4 columns]

# %%
df['Preco m2 [BTC]'] = df['Preco m2 [EUR]']/df['Price']
df
# Out:
#           Date     Price  year  Preco m2 [EUR]  Preco m2 [BTC]
# 0   2025-09-01   97190.7  2025            2943        0.030281
# 1   2025-08-01   92600.0  2025            2951        0.031868
# 2   2025-07-01  101384.8  2025            2926        0.028860
# 3   2025-06-01   91358.6  2025            2898        0.031721
# 4   2025-05-01   92278.0  2025            2851        0.030896
# ..         ...       ...   ...             ...             ...
# 124 2015-05-01     208.3  2015            1103        5.295247
# 125 2015-04-01     210.3  2015            1078        5.126010
# 126 2015-03-01     228.4  2015            1078        4.719790
# 127 2015-02-01     220.9  2015            1068        4.834767
# 128 2015-01-01     193.5  2015             969        5.007752
#
# [129 rows x 5 columns]

# %%
df = df.sort_values('Date', ascending=True).reset_index()

# %%
df.head()
# Out:
#    index       Date  Price  year  Preco m2 [EUR]  Preco m2 [BTC]
# 0    128 2015-01-01  193.5  2015             969        5.007752
# 1    127 2015-02-01  220.9  2015            1068        4.834767
# 2    126 2015-03-01  228.4  2015            1078        4.719790
# 3    125 2015-04-01  210.3  2015            1078        5.126010
# 4    124 2015-05-01  208.3  2015            1103        5.295247

# %%
# Create the plot with dual y-axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot house prices on left y-axis
color1 = 'tab:blue'
ax1.set_xlabel('Date')


ax1.set_ylabel('Preço por m² (EUR)', color='green')
ax1.plot(df['Date'], df['Preco m2 [EUR]'], color='green', marker='o', label='Preço/m² [EUR]')
ax1.tick_params(axis='y', labelcolor='green')
ax1.grid(True, alpha=0.3)

# Create second y-axis for Bitcoin price
ax2 = ax1.twinx()
color2 = 'tab:orange'
ax2.set_ylabel('Preço por m² (BTC)', color=color2)

ax2.set_yscale('log')
ax2.yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=False))

ax2.plot(df['Date'], df['Preco m2 [BTC]'], color=color2, marker='s', label='Preço/m² [BTC]')
ax2.tick_params(axis='y', labelcolor=color2)

# Add title and legends
plt.title('Preço por m² em Portugal - EUR vs BTC', fontsize=14, fontweight='bold')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# making a new graph with only data from 2020

df_2020 = df[df['Date'] >= '2020-01-01']

# %%
# Export to standalone HTML file (optional)
# Uncomment the line below to save the interactive graph as HTML
# fig.write_html("preco_m2_portugal_interactive.html")
